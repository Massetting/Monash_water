# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
from scipy import ndimage

# %%
plt.imshow(np.ones((100,100)))

# %%
noisy_image = np.random.random_sample((100,100))
plt.imshow(noisy_image)

# %%
filtered = ndimage.median_filter(noisy_image, size=(3,3))
plt.imshow(filtered)

# %%
data = r"C:\Users\User\Documents\PhD Documents\Scripts\Monash_water\data\Landsat_8_2013.nc"
LS = xr.open_dataset(data)

# %%
LS.red
# Out:
# <xarray.DataArray 'red' (time: 56, y: 4000, x: 4000)>
# [896000000 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 2013-03-26T00:10:52 ... 2013-12-29T00:05:16
#   * y        (y) float64 -4.2e+06 -4.2e+06 -4.2e+06 ... -4.3e+06 -4.3e+06
#   * x        (x) float64 1.1e+06 1.1e+06 1.1e+06 ... 1.2e+06 1.2e+06 1.2e+06
# Attributes:
#     grid_mapping:  crs
#     units:         1
#     long_name:     Nadir BRDF Adjusted Reflectance 0.64-0.67 microns (Red)
#     alias:         band_4

# %%
red = LS.nir 
(red.isel(time=20).sel(x=slice(1115000,1120000),y=slice(-4225000,-4230000))/10000).plot.imshow()
plt.show()
